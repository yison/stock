# %%
import tushare as ts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils
import os

def tracking_model_001(df, max_count):
    ## clean data
    df = df.replace('买盘', 'buy').replace('卖盘', 'sell')
    df_trans = df[['time', 'price', 'volume', 'amount', 'type']]
    df_trans = df_trans[df_trans['volume'] > 0].dropna()
    df_trans = df_trans[df_trans['amount'] > 9000]
    
    head_max_count = df_trans.volume.value_counts().head(max_count)
    print (head_max_count)
    count = 0
    count_list = []
    for i in head_max_count.index:
        _df = df_trans[df_trans.volume == i]
        _df.time = pd.to_datetime(_df.time)
        _df_trans = _df.set_index('time')
        
        df_count = _df_trans.to_period('T').index.value_counts().rename('mins_count').to_frame()
        df_resample_10m = df_count.resample('10T').sum().dropna()
        df_resample_10m_filtered = df_resample_10m[df_resample_10m >= 20].dropna()
        df_resample_20m = df_count.resample('20T').sum().dropna()
        df_resample_20m_filtered = df_resample_20m[df_resample_20m >= 40].dropna()
        df_count_new = df_count[df_count.mins_count > 3].sort_index()
        
        pct_type = _df_trans.type.value_counts(normalize=True)
        total_vol_type_amount = pct_type[0] * _df_trans.amount.sum()
        day_amount = df_trans.amount.sum()
        amount_pct = total_vol_type_amount / day_amount
        print (i, pct_type, total_vol_type_amount, amount_pct, df_resample_10m_filtered, df_resample_20m_filtered, df_count_new)
#         df_count = _df_trans.to_period('T').index.value_counts().rename('mins_count').to_frame()
#         print (df_count.head())
        
#         df_resample_10m_filtered = df_count.resample('10T').sum().dropna()
       
#         df_count_new = df_count[df_count.mins_count > 3].sort_index()
        
#         if (df_count_new.mins_count.count() > 10 and df_resample_10m_filtered.mins_count.count() > 3):
#             count = count + 1
#             count_list.append((i, df_resample_10m_filtered, df_count_new,))
    return (count_list)



# df = pd.read_csv("hello.csv")
# max_count = 5
# res = tracking_model_001(df, max_count)
# print (res)


# def filter_df_col_zero(df, column_name):
#     return df[df[column_name] > 0][column_name]

# def get_filtered_sorted_stocks():
#     stocks_df = ts.get_stock_basics()
#     sorted_stocks_df = stocks_df.sort_index()
#     return sorted_stocks_df

# max_count = 5
# stocks = get_filtered_sorted_stocks()
# stock_list = filter_df_col_zero(stocks, 'timeToMarket')
# # print (stock_list)
# for j in stock_list.index:
#     df = ts.get_tick_data(j, date='2018-02-23')
#     res = tracking_model_001(df, max_count)
#     if len(res) > 0:
#         print (j)
#         print (res)
max_count = 10

# path = "/home/cloud001/ly/mygithub/stock/data/trading/history/day"
# day = "2018-03-26"
# day_path = os.path.join(path, day)
# file_mapping_list = utils.find_files(day_path)
# df = pd.DataFrame(columns=['amount'])
# for (code, file_path) in file_mapping_list:
#     _df = pd.read_csv(file_path)
# #     _df=_df['amount'].to_frame()
# #     print (_df)
# #     pd.merge(df, _df, on='amount')
# #     print (df)
#     if code == "603758":
#         res = tracking_model_001(_df, max_count)
#         if len(res) > 0:
#             print (res)
# #         print (_df[_df.volume.isin(['36','37','38'])])

path = "/home/cloud001/ly/mygithub/stock/data/trading/history/day"
date = "2018-03-05"
code = "600023"

file_path = os.path.join(os.path.join(path,date), code)
df = pd.read_csv(file_path)
res = tracking_model_001(df, max_count)
print (res)
# Out:
# 18    313
# 25    274
# 19    114
# 24     88
# 20     58
# 26     42
# 27     42
# 30     41
# 22     32
# 50     28
# Name: volume, dtype: int64
# 18 buy     0.971246
# sell    0.028754
# Name: type, dtype: float64 3071987.98722 0.0344618580029                      mins_count
# 2018-04-03 13:10:00        34.0
# 2018-04-03 13:20:00        33.0
# 2018-04-03 13:30:00        27.0
# 2018-04-03 13:40:00        33.0
# 2018-04-03 13:50:00        35.0
# 2018-04-03 14:00:00        21.0
# 2018-04-03 14:10:00        34.0
# 2018-04-03 14:20:00        27.0
# 2018-04-03 14:30:00        25.0
# 2018-04-03 14:40:00        23.0                      mins_count
# 2018-04-03 13:00:00        44.0
# 2018-04-03 13:20:00        60.0
# 2018-04-03 13:40:00        68.0
# 2018-04-03 14:00:00        55.0
# 2018-04-03 14:20:00        52.0                   mins_count
# 2018-04-03 13:09           4
# 2018-04-03 13:12           4
# 2018-04-03 13:13           5
# 2018-04-03 13:15           4
# 2018-04-03 13:18           5
# 2018-04-03 13:20           4
# 2018-04-03 13:26           6
# 2018-04-03 13:28           4
# 2018-04-03 13:30           5
# 2018-04-03 13:31           4
# 2018-04-03 13:33           5
# 2018-04-03 13:42           4
# 2018-04-03 13:43           5
# 2018-04-03 13:44           5
# 2018-04-03 13:51           5
# 2018-04-03 13:52           4
# 2018-04-03 13:54           5
# 2018-04-03 13:56           4
# 2018-04-03 13:57           4
# 2018-04-03 14:08           4
# 2018-04-03 14:12           5
# 2018-04-03 14:17           5
# 2018-04-03 14:18           4
# 2018-04-03 14:19           4
# 2018-04-03 14:24           5
# 2018-04-03 14:26           4
# 2018-04-03 14:29           4
# 2018-04-03 14:30           5
# 25 buy     0.945255
# sell    0.054745
# Name: type, dtype: float64 3631681.93066 0.0407405587283                      mins_count
# 2018-04-03 10:00:00        23.0
# 2018-04-03 10:10:00        27.0
# 2018-04-03 10:20:00        21.0
# 2018-04-03 10:30:00        28.0
# 2018-04-03 10:40:00        29.0
# 2018-04-03 10:50:00        27.0
# 2018-04-03 11:00:00        30.0
# 2018-04-03 11:10:00        32.0                      mins_count
# 2018-04-03 10:00:00        50.0
# 2018-04-03 10:20:00        49.0
# 2018-04-03 10:40:00        56.0
# 2018-04-03 11:00:00        62.0                   mins_count
# 2018-04-03 10:02           4
# 2018-04-03 10:07           5
# 2018-04-03 10:12           4
# 2018-04-03 10:15           4
# 2018-04-03 10:21           4
# 2018-04-03 10:22           4
# 2018-04-03 10:23           4
# 2018-04-03 10:28           4
# 2018-04-03 10:31           5
# 2018-04-03 10:36           5
# 2018-04-03 10:41           5
# 2018-04-03 10:45           4
# 2018-04-03 10:46           4
# 2018-04-03 10:53           4
# 2018-04-03 10:57           4
# 2018-04-03 10:58           5
# 2018-04-03 10:59           5
# 2018-04-03 11:03           5
# 2018-04-03 11:07           4
# 2018-04-03 11:09           4
# 2018-04-03 11:10           4
# 2018-04-03 11:11           4
# 2018-04-03 11:12           4
# 2018-04-03 11:14           4
# 2018-04-03 11:19           5
# /home/cloud001/ly/mygithub/stock/local/lib/python3.5/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 19 buy     0.833333
# sell    0.166667
# Name: type, dtype: float64 1013073.33333 0.0113647545189 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 24 buy     0.931818
# sell    0.068182
# Name: type, dtype: float64 1103978.11364 0.012384533126 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 20 sell    0.534483
# buy     0.465517
# Name: type, dtype: float64 347523.896552 0.00389855664325 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 26 buy     0.690476
# sell    0.309524
# Name: type, dtype: float64 422893.880952 0.0047440644092 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 27 buy     0.714286
# sell    0.285714
# Name: type, dtype: float64 454187.142857 0.00509511524426 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 30 buy     0.512195
# sell    0.487805
# Name: type, dtype: float64 353103.219512 0.0039611460272 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 22 buy     0.625
# sell    0.375
# Name: type, dtype: float64 246511.875 0.00276539402745 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# 50 buy     0.571429
# sell    0.428571
# Name: type, dtype: float64 447940.0 0.0050250341922 Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: [] Empty DataFrame
# Columns: [mins_count]
# Index: []
# []
